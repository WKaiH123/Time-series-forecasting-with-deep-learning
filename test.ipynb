# %%
import pandas as pd
from Packaging import models
import warnings
import numpy as np
warnings.filterwarnings("ignore")

# %%
world_data = pd.read_csv(r'.\energy_data.csv')

# %%
training_data = world_data['sum']       #输入单序列
print(training_data.shape)
# training_data = np.random.random((1363))
# training_data = pd.Series(training_data.tolist())
# print(training_data.shape)
# Out:
# (1774,)

# %%
import numpy as np 
import matplotlib.pyplot as plt 
plt.figure(figsize=(8,6))
plt.plot(training_data,'r',linestyle='--')
#plt.savefig('./figure/LogTrans_14-1_fitting.jpg')
plt.show()

# %%
models().RNN(training_data,0.7,7,1)
# Out:
# x_train : torch.Size([1233, 1, 7]), y_train : torch.Size([1233, 1]), x_test : torch.Size([526, 1, 7]), y_test : torch.Size([526, 1])

# %%
models().TCN(training_data,0.7,7,1)
# Out:
# x_train : torch.Size([1233, 1, 7]), y_train : torch.Size([1233, 1]), x_test : torch.Size([526, 1, 7]), y_test : torch.Size([526, 1])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-835b91e77e1c> in <module>
# ----> 1 models().TCN(training_data,0.7,7,1)
#
# E:\Lab\github项目\Packaging.py in TCN(self, data, train_test_rate, time_step, skip)
#    1259                 output = tcn(inp)
#    1260                 loss = F.mse_loss(output, target)
# -> 1261                 loss.backward()
#    1262                 total_loss += loss
#    1263                 if clip > 0:
#
# d:\programs\python\python39\lib\site-packages\torch\_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# d:\programs\python\python39\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     152         retain_graph = create_graph
#     153
# --> 154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
models().LSTM(training_data,0.7,7,1)
# Out:
# x_train : torch.Size([1233, 1, 7]), y_train : torch.Size([1233, 1]), x_test : torch.Size([526, 1, 7]), y_test : torch.Size([526, 1])

# %%
models().MLP(training_data,0.7,7,1)

# %%
models().GRU(training_data,0.7,7,1)

# %%
models().XGB(training_data,0.7,7,1)

# %%
models().ARIMA(training_data,0.7,7,1)

# %%
models().BLS(training_data,0.7,7,1)
